# %%
import tensorflow as tf
import os
from google.colab import drive

# Drive the mount
drive.mount('/drive')
print("Drive mounted!")

# Load the model from drive
model = tf.keras.models.load_model('/drive/MyDrive/detectderm_best_model.h5')
print(" Model loaded!")

# TFLite convert
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()
print("Converted!")

# For save
with open('/content/detectderm_model.tflite', 'wb') as f:
    f.write(tflite_model)

# Size check
h5_size = os.path.getsize('/drive/MyDrive/detectderm_best_model.h5') / (1024*1024)
tflite_size = os.path.getsize('/content/detectderm_model.tflite') / (1024*1024)
print(f".h5 size:     {h5_size:.2f} MB")
print(f".tflite size: {tflite_size:.2f} MB")

# Save on the Drive
import shutil
shutil.copy('/content/detectderm_model.tflite',
            '/drive/MyDrive/detectderm_model.tflite')
print("Saved on the Drive")
# Out:
# Mounted at /drive
# Drive mounted!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#  Model loaded!
# Saved artifact at '/tmp/tmpgz_yulmf'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   135816593317264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135816593319568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135816593319376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135816593318992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135816593317648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135816593316688: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...

# %%
# Download on Computer
from google.colab import files
files.download('/content/detectderm_model.tflite')
